# %% [markdown]
#                              INTRODUCTION
#  In this Project we are going to deal with diabetes dataset and how it is affeccting various attributes.The Information provided in our data set includes Age,BMI,Diabetes Pedigree Function,Insulin,Glucose and Blood Pressure.Our main objective in this project to find that how diabetic and non diabetic persons are affecting these attributes and how can we deal with it.For this purpose i have plot many graphs so we can interpret the results clearly and our study on this project will be more keen and effective.

# %%
# importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
# Reading the file
var = pd.read_excel('Variables_diabetes_EDA.xlsx')
df = pd.read_excel('diabetes_mandatory_EDA.xlsx',names=var["Variables used"])

# %%
# Reading top 5 rows
df.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  Skin Thickness  Insulin   BMI  \
# 0          1.0     85.0            66.0            29.0      0.0  26.6
# 1          8.0    183.0            64.0             0.0      0.0  23.3
# 2          1.0     89.0            66.0            23.0     94.0  28.1
# 3          0.0    137.0            40.0            35.0    168.0  43.1
# 4          5.0    116.0            74.0             0.0      0.0  25.6
#
#    Diabetes Pedigree Function   Age  Outcome
# 0                       0.351  31.0      0.0
# 1                       0.672  32.0      1.0
# 2                       0.167  21.0      0.0
# 3                       2.288  33.0      1.0
# 4                       0.201  30.0      0.0

# %%
#getting information about dataset that how many total values are there and in which column we have null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 767 non-null    float64
#  1   Glucose                     767 non-null    float64
#  2   Blood Pressure              767 non-null    float64
#  3   Skin Thickness              767 non-null    float64
#  4   Insulin                     767 non-null    float64
#  5   BMI                         767 non-null    float64
#  6   Diabetes Pedigree Function  767 non-null    float64
#  7   Age                         767 non-null    float64
#  8   Outcome                     767 non-null    float64
# dtypes: float64(9)
# memory usage: 54.1 KB

# %%
# getting total number of rows and columns in the given data set
df.shape
# Out:
# (767, 9)

# %%
updated_df = df
updated_df['Insulin']=updated_df['Insulin'].fillna(updated_df['Insulin'].mean())
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 767 non-null    float64
#  1   Glucose                     767 non-null    float64
#  2   Blood Pressure              767 non-null    float64
#  3   Skin Thickness              767 non-null    float64
#  4   Insulin                     767 non-null    float64
#  5   BMI                         767 non-null    float64
#  6   Diabetes Pedigree Function  767 non-null    float64
#  7   Age                         767 non-null    float64
#  8   Outcome                     767 non-null    float64
# dtypes: float64(9)
# memory usage: 54.1 KB

# %% [markdown]
# In some places insulin is filling with 0 means that is missing value because insulin cannot be 0 so replacing it with mean.

# %%
# Checking null values
df.isna().any()
# Out:
# Pregnancies                   False
# Glucose                       False
# Blood Pressure                False
# Skin Thickness                False
# Insulin                       False
# BMI                           False
# Diabetes Pedigree Function    False
# Age                           False
# Outcome                       False
# dtype: bool

# %%
# getting information about mean,median,quartiles of the specific columns
df.describe()
# Out:
#        Pregnancies     Glucose  Blood Pressure  Skin Thickness     Insulin  \
# count   767.000000  767.000000      767.000000      767.000000  767.000000
# mean      3.842243  120.859192       69.101695       20.517601   79.903520
# std       3.370877   31.978468       19.368155       15.954059  115.283105
# min       0.000000    0.000000        0.000000        0.000000    0.000000
# 25%       1.000000   99.000000       62.000000        0.000000    0.000000
# 50%       3.000000  117.000000       72.000000       23.000000   32.000000
# 75%       6.000000  140.000000       80.000000       32.000000  127.500000
# max      17.000000  199.000000      122.000000       99.000000  846.000000
#
#               BMI  Diabetes Pedigree Function         Age     Outcome
# count  767.000000                  767.000000  767.000000  767.000000
# mean    31.990482                    0.471674   33.219035    0.348110
# std      7.889091                    0.331497   11.752296    0.476682
# ...

# %%
sns.countplot(x="Outcome",data=df)
plt.title("Diabetic vs Non Diabetic")
# Out:
# Text(0.5, 1.0, 'Diabetic vs Non Diabetic')

# %% [markdown]
# Getting total count of diabetic and non diabetic patients

# %%
df['Outcome'].value_counts()
# Out:
# 0.0    500
# 1.0    267
# Name: Outcome, dtype: int64

# %% [markdown]
# Total diabetic patient is 267 and non diabetic patient is 500

# %%
sns.barplot(x='Outcome',y='Glucose',data=df)
plt.title("Glucose level diabetic and non diabetic")
# Out:
# Text(0.5, 1.0, 'Glucose level diabetic and non diabetic')

# %% [markdown]
# Graph is clearly representing that glucose level of non diabetic patient is around 110 and for diabetic patient it is around 140

# %%
sns.barplot(x='Outcome',y='Pregnancies',data=df)
plt.title("Pregnancies of diabetic and non diabetic")
# Out:
# Text(0.5, 1.0, 'Pregnancies of diabetic and non diabetic')

# %% [markdown]
# The Graph Represents that higher the count of pregnancies more the diabetic is person and lesser the count of pregnancies less the diabetic is person.

# %%
sns.barplot(x='Outcome',y='Skin Thickness',data=df)
plt.title("Skin Thickness diabetic and non diabetic")
# Out:
# Text(0.5, 1.0, 'Skin Thickness diabetic and non diabetic')

# %% [markdown]
# Skin Thickness of diabetic patient is more than the non diabetic patient.

# %%
sns.barplot(x='Outcome',y='BMI',data=df)
plt.title("BMI ofdiabetic and non diabetic")
# Out:
# Text(0.5, 1.0, 'BMI ofdiabetic and non diabetic')

# %% [markdown]
# Body mass index of diabetic patient is more than the non diabetic patient.

# %%
sns.barplot(x='Outcome',y='Diabetes Pedigree Function',data=df)
plt.title("Diabetes Pedigree Function of diabetic and non diabetic")
# Out:
# Text(0.5, 1.0, 'Diabetes Pedigree Function of diabetic and non diabetic')

# %% [markdown]
# The Graph represents that Diabetes Pedigree function of diabetic person is more than non diabetic person

# %%
sns.barplot(x='Outcome',y='Blood Pressure',data=df)
plt.title("Blood Pressure of diabetic and non diabetic")
# Out:
# Text(0.5, 1.0, 'Blood Pressure of diabetic and non diabetic')

# %% [markdown]
# From the figure it is clear that there is slightly difference in blood presure level of diabetic and non diabetic person although blood preesure of diabetic person is slightly higher thn non diabetic person.

# %%
sns.barplot(x='Outcome',y='Insulin',data=df)
plt.title("Insulin of diabetic and non diabetic")
# Out:
# Text(0.5, 1.0, 'Insulin of diabetic and non diabetic')

# %% [markdown]
# The graph clearly shows that insulin level of diabetic person is much more than the insulin level of non diabetic person.

# %%
sns.barplot(x='Outcome',y='Age',data=df)
plt.title("Age of diabetic and non diabetic")
# Out:
# Text(0.5, 1.0, 'Age of diabetic and non diabetic')

# %% [markdown]
# We can interpret from this figure that as the age increases chance of becoming a diabetic is more.

# %% [markdown]
# FINDING OUTLIERS AND TRYING TO DEAL WITH IT

# %%
sns.boxplot(x='Pregnancies',hue='Outcome',data=df)

# %% [markdown]
# We can clearly see that outliers are present in the graph.

# %%
Q1=df.quantile(0.25)
Q1
# Out:
# Pregnancies                    1.0000
# Glucose                       99.0000
# Blood Pressure                62.0000
# Skin Thickness                 0.0000
# Insulin                        0.0000
# BMI                           27.3000
# Diabetes Pedigree Function     0.2435
# Age                           24.0000
# Outcome                        0.0000
# Name: 0.25, dtype: float64

# %% [markdown]
# Finding the Quartile range(Q1) for our data as we need it in removing the outliers during IQR process.

# %%
Q3=df.quantile(0.75)
Q3
# Out:
# Pregnancies                     6.000
# Glucose                       140.000
# Blood Pressure                 80.000
# Skin Thickness                 32.000
# Insulin                       127.500
# BMI                            36.600
# Diabetes Pedigree Function      0.625
# Age                            41.000
# Outcome                         1.000
# Name: 0.75, dtype: float64

# %% [markdown]
# Similarly finding the Quartile range(Q3) for our data as we need it in removing the outliers during IQR process

# %%
from scipy import stats
IQR= stats.iqr(df.Pregnancies,interpolation='midpoint')

print(IQR)
# Out:
# 5.0

# %% [markdown]
# Finding Inter Quartile Range

# %%
lower_limit=1-(1.5*5)
upper_limit=6+(1.5*5)

# %% [markdown]
# Finding Upper Limit And lower limit range for the pregnancies data.

# %%
(lower_limit,upper_limit)
# Out:
# (-6.5, 13.5)

# %% [markdown]
# This is the range between which our data lies after removing the outliers,

# %%
sns.boxplot(x='Glucose',data=df)

# %% [markdown]
# In this graph outliers are also Present.

# %%
from scipy import stats
IQR= stats.iqr(df.Glucose,interpolation='midpoint')

print(IQR)
# Out:
# 41.0

# %% [markdown]
# Finding The Inter Quartile Range

# %%
lower_limit=99-(1.5*41)
upper_limit=140+(1.5*41)

# %% [markdown]
# Finding Upper Limit And lower limit range for the Glucose data.

# %%
(lower_limit,upper_limit)
# Out:
# (37.5, 201.5)

# %% [markdown]
# This is the range in which the useful data lies after removing the outliers.

# %%
sns.boxplot(x='BMI',data=df)

# %% [markdown]
# Similarly the ouliers are also present in this graph.

# %%
from scipy import stats
IQR= stats.iqr(df.BMI,interpolation='midpoint')

print(IQR)
# Out:
# 9.3

# %% [markdown]
# Finding The Inter Quartile Range

# %%
lower_limit=27.3-(1.5*9.3)
upper_limit=36.6+(1.5*9.3)

# %% [markdown]
# Finding Upper Limit And lower limit range for the BMI data.

# %%
(lower_limit,upper_limit)
# Out:
# (13.35, 50.550000000000004)

# %% [markdown]
# This is the range in which the useful data lies after removing the outliers.

# %%
sns.scatterplot(x="Age",y="Pregnancies",hue="Outcome",data=df)
plt.title("Scatter plot between age and pregnancies with outcome as a legend")
# Out:
# Text(0.5, 1.0, 'Scatter plot between age and pregnancies with outcome as a legend')

# %% [markdown]
# We can interpret from this graph that People between age group 20 t0 30 are less diabetic and the pregnancy case is also low in this group age as the age group increases between 30 to 40 the diabetic patients are increasing as well as the pregnancy case are also increasing as the ase goes betwee 40 to 50 rise in diabetic parient is more but pregnancies case is decreasing slightly.AS Age level is between 50 to 60 diabetic patient is more as we sse that age group is increaing people becoming more diabetic but there is any pregnancy case at higher Age it is almost negligible.

# %%
sns.scatterplot(x="Insulin",y="Pregnancies",hue="Outcome",data=df)
plt.title("Scatter plot between Pregnancies and Insulin with outcome as a legend")
# Out:
# Text(0.5, 1.0, 'Scatter plot between Pregnancies and Insulin with outcome as a legend')

# %% [markdown]
# We can see from the graph that When the insulin level is between 0 to 200 most of the person are non diabetic but the Preganancies case are more as the insulin level rises the pregnancies case are decreasing but the rise in diabetic patient is more with increase in the insulin level.

# %%
sns.scatterplot(y="Glucose",x="Age",hue="Outcome",data=df)
plt.title("Scatter plot between Pregnancies and Glucose with outcome as a legend")
# Out:
# Text(0.5, 1.0, 'Scatter plot between Pregnancies and Glucose with outcome as a legend')

# %% [markdown]
# It is clear from the graph that most of the people between agr group 20 to 30 are non diabetic and generally there glucose level is between 75 to 110.As age is between 30 to 40 diabetic case increases and some people are dibetic even with low glucose level.As age increases between 40 to 50 case of diabetes increases but the glucose level is not so high as we see in other age group.As age goes from 50 to 60 we can see that glucose level is more.Again in the age group 60-70 that people are no that much diabetic as in other age group. AS we proceed further diabetes cases are becoming negligible with increase in age.

# %%
sns.scatterplot(x="Age",y="BMI",hue="Outcome",data=df)
plt.title("Scatter plot between Pregnancies and Glucose with outcome as a legend")
# Out:
# Text(0.5, 1.0, 'Scatter plot between Pregnancies and Glucose with outcome as a legend')

# %% [markdown]
# We can see from the graph that people between 20 to 30 are not that much diabetic but having high body mass index.But as the age is increasing there is rise in diabetic patient but with the rise in age body mass index is decreaisng.As the age is going above 60 suddenly we can see that diabetic case is decreasing very rapidly and above 70 years of age there is hardly any diabetic case but the body mass index is very low.

# %%
# Checking the skewness of our data.
df.skew()
# Out:
# Pregnancies                   0.903976
# Glucose                       0.176412
# Blood Pressure               -1.841911
# Skin Thickness                0.112058
# Insulin                      -1.159867
# BMI                          -0.427950
# Diabetes Pedigree Function    1.921190
# Age                           0.605544
# Outcome                       0.638949
# dtype: float64

# %%
sns.histplot(data = df['Age'], kde = True)
plt.axvline(x=df.Age.mean(),color='red',alpha=0.5,label='Mean')
plt.axvline(x=df.Age.median(),c='blue',ls='--',alpha=0.5,label='Median')
plt.legend()

# %% [markdown]
# From the above graph we can see tht graph is positively skewed

# %%
# Doing log transformation for removing the Skewness
df['Age'] = np.log(df['Age'])

# %%
sns.distplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Doing log transformation for removing the Skewness
df['Age'] = np.log(df['Age'])

# %%
sns.distplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Most of thhe useful data lies between value 1.1 to 1.25 ansd the skewness is removed from the graph.

# %% [markdown]
# From our study we have found various details about diabetic and non diabetic person and i have come to a result that diabetes is really a challenging condion as it is affecting people of every age group.women with pregnancies are also affected by it.IT also create problem in the BMI and Blood Pressure level of the person.

# %% [markdown]
#                                  Conclusion
# The concluion of our project is that How diabetic and non diabetic persons are affectiong our data set.From our study it is concluded that person with High glucose or insulin level are generally diabetic. In this project we have also deal with outliers ansd skewness and try to remove them. We have plot various bar graph and scatter plot to visualize the data more clearly so we can come to the proper result and explain the each graph what the graph basically represents.We have also try to find the null values and give all the information about our data as required in the study process.
